# %%
from tensorflow.keras.layers import MaxPooling2D, Conv2D
import numpy as np
import tensorflow as tf

# Step 2 (30 points)
def net48_siso(): 
    height, width = 48, 48
    inputs = tf.keras.Input((height, width, 3));
    x = Conv2D(8, 3, 1, 'same', activation='relu')(inputs)
    # enter your code here
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(16, 3, 1, 'same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(32, 3, 1, 'same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(64, 3, 1, 'same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(128, 3, 1, 'same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Conv2D(2, 1, 1, 'same', activation='softmax', name='cls_output')(x)

    outputs = x
    return tf.keras.Model(inputs = inputs, outputs = outputs)

# %%
# Step 3 (15 points)
def net48_simo(): 
    height, width = 48, 48
    inputs = tf.keras.Input((height, width, 3));
    x = Conv2D(8,3,1,'same',activation='relu')(inputs)
    # enter your code here
    # The first output
    x1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x1 = Conv2D(16, 3, 1, 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x1)
    x1 = Conv2D(32, 3, 1, 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x1)
    x1 = Conv2D(64, 3, 1, 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x1)
    x1 = Conv2D(128, 3, 1, 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x1)
    x1 = Conv2D(2, 1, 1, 'same', activation='softmax', name='cls_output')(x1)
    
    # The second output
    x2 = MaxPooling2D(2)(x)
    x2 = Conv2D(16, 3, 1, 'same', activation='relu')(x2)
    x2 = MaxPooling2D(2)(x2)
    x2 = Conv2D(32, 3, 1, 'same', activation='relu')(x2)
    x2 = MaxPooling2D(2)(x2)
    x2 = Conv2D(64, 3, 1, 'same', activation='relu')(x2)
    x2 = MaxPooling2D(2)(x2)
    x2 = Conv2D(128, 3, 1, 'same', activation='relu')(x2)
    x2 = MaxPooling2D(2)(x2)
    x2 = Conv2D(4, 1, 1, 'same', name='reg_output')(x2)
    
    outputs = list()
    outputs.append(x1)
    outputs.append(x2)
    # you need to modify the following line
    return tf.keras.Model(inputs = inputs, outputs = outputs)

# %%
# Do not change below.
def check_model(cnn_model, is_simo=False):
  print('Checking the CNN model...')
  is_passed = True
  is_cls_output = False
  is_reg_output = False
  ishape = cnn_model.input_shape[1:]
  if (48,48,3) != ishape:
     print('Error! The input shape', ishape, 'is not equal to (48,48,3)')
     is_passed = False
  for i,layer in enumerate(cnn_model.layers):
     if layer.name == 'cls_output':
       oshape = layer.output_shape[1:]
       is_cls_output = True
       if (1,1,2) != oshape:
          print('Error! The output shape', oshape, 'is not equal to (1,1,2)')
          is_passed = False
     if layer.name == 'reg_output':
       oshape = layer.output_shape[1:]
       is_reg_output = True
       if (1,1,4) != oshape:
          print('Error! The output shape', oshape, 'is not equal to (1,1,4)')
          is_passed = False
     layer_type = layer.__class__.__name__
     if layer_type == 'Dense':
       print('Error! Cannot use Dense layers.')
       is_passed = False
     if layer_type == 'Conv2D':
       kernel_size = layer.kernel_size
       strides = layer.strides
       if np.max(kernel_size) > 7:
         print('({:d} {:s}) Error! kernel_size should be less than or equal to 7'.format(i, layer_type))
         is_passed = False
       if np.max(strides) > 2:
         print('({:d} {:s}) Error! stride should be less than or equal to 2'.format(i, layer_type))
         is_passed = False
     if layer_type == 'MaxPooling2D':
       pool_size = layer.pool_size
       strides = layer.strides
       if np.max(pool_size) > 2:
         print('({:d} {:s}) Error! pool_size should be less than or equal to 2'.format(i, layer_type))
         is_passed = False
       if np.max(strides) > 2:
         print('({:d} {:s}) Error! stride should be less than or equal to 2'.format(i, layer_type))
         is_passed = False
  if not is_cls_output:
     print('Error! There should be a Conv. layer with name cls_output')
     is_passed = False
  if is_simo:
     if not is_reg_output:
       print('Error! There should be a Conv. layer with name reg_output')
       is_passed = False
  if is_passed:
     print('Great! The CNN model satisfies all the requirements.')

# %%
# Do not change below.
model48_siso = net48_siso()
model48_siso.summary()
check_model(model48_siso)
print()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 8)         224
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 64)          18496
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  cls_output (Conv2D)         (None, 1, 1, 2)           258
#
# =================================================================
# Total params: 98,642
# Trainable params: 98,642
# Non-trainable params: 0
# _________________________________________________________________
# Checking the CNN model...
# Great! The CNN model satisfies all the requirements.

# %%
# Do not change below.
model48_simo = net48_simo()
model48_simo.summary()
check_model(model48_simo, is_simo=True)
print()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d_5 (Conv2D)              (None, 48, 48, 8)    224         ['input_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 24, 24, 8)   0           ['conv2d_5[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 24, 24, 8)   0           ['conv2d_5[0][0]']
#  )
#
#  conv2d_6 (Conv2D)              (None, 24, 24, 16)   1168        ['max_pooling2d_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 24, 16)   1168        ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 16)  0           ['conv2d_6[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 12, 12, 16)  0           ['conv2d_10[0][0]']
#  )
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 32)   4640        ['max_pooling2d_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 32)   4640        ['max_pooling2d_11[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 32)    0           ['conv2d_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 6, 6, 32)    0           ['conv2d_11[0][0]']
#  )
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 64)     18496       ['max_pooling2d_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 6, 6, 64)     18496       ['max_pooling2d_12[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 64)    0           ['conv2d_8[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 3, 3, 64)    0           ['conv2d_12[0][0]']
#  )
#
#  conv2d_9 (Conv2D)              (None, 3, 3, 128)    73856       ['max_pooling2d_8[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 3, 3, 128)    73856       ['max_pooling2d_13[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 128)   0           ['conv2d_9[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 1, 1, 128)   0           ['conv2d_13[0][0]']
#  )
#
#  cls_output (Conv2D)            (None, 1, 1, 2)      258         ['max_pooling2d_9[0][0]']
#
#  reg_output (Conv2D)            (None, 1, 1, 4)      516         ['max_pooling2d_14[0][0]']
#
# ==================================================================================================
# Total params: 197,318
# Trainable params: 197,318
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Checking the CNN model...
# Great! The CNN model satisfies all the requirements.

# %%
# Do not change below.
img = np.random.randn(1, 48, 48, 3)
outputs = model48_simo.predict(img)
print(outputs[0].shape) # should display (1,1,1,2)
print(outputs[1].shape) # should display (1,1,1,4)
cls = np.reshape(outputs[0], (2,))
reg = np.reshape(outputs[1], (4,))
print(cls)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# (1, 1, 1, 2)
# (1, 1, 1, 4)
# [0.54510415 0.45489585]

# %%
# Question 2 (5 points)
# Why cls[0] + cls[1] is always equal to one regardless of  the values of img?
# Answer：
# 因我們將分類輸出通過softmax函數，它接受一個數字向量並輸出一個概率分佈，其中輸出向量中的每個元素表示對應類別的概率。
# softmax函數會對輸出向量進行歸一化，使向量中所有元素的總和等於1。因此，如果分類輸出包含兩個類別，那麼cls[0]和cls[1]
# 的總和始終會等於1，而不管輸入圖像的值是什麼。
